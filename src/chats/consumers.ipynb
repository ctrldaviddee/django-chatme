# %%
data = {
    'groups': [], 
    'scope': {
        'type': 'websocket', 
        'path': '/ws/chatroom/public-chat', 
        'raw_path': b'/ws/chatroom/public-chat', 
        'root_path': '', 
        'headers': [
            (b'host', b'localhost:8000'), 
            (b'user-agent', b'Mozilla/5.0 (X11; Ubuntu; Linux x86_64; rv:139.0) Gecko/20100101 Firefox/139.0'), 
            (b'accept', b'*/*'), 
            (b'accept-language', b'en-US,en;q=0.5'), 
            (b'accept-encoding', b'gzip, deflate, br, zstd'), 
            (b'sec-websocket-version', b'13'), 
            (b'origin', b'http://localhost:8000'), 
            (b'sec-websocket-extensions', b'permessage-deflate'), 
            (b'sec-websocket-key', b'aXVE35ckoTW9YQlYxPp1rg=='), 
            (b'connection', b'keep-alive, Upgrade'), 
            (b'cookie', b'csrftoken=xa6Vc2LB1UqGcRcvJcD7ubSbmJhOfaQF; _ga_S5QK8VSK84=GS1.1.1740562390.1.1.1740562437.13.0.0; _ga=GA1.1.722471364.1740562390; i18n_redirected=fr; Idea-222ad569=948cdcf9-49b0-49fd-8e7e-619d82b129df; _ga_GQJEC1951X=GS2.1.s1749050054$o5$g1$t1749050111$j3$l0$h1403485809; _gcl_au=1.1.732818395.1748874880; __hstc=181257784.6792f2d6059cc1bc58f90e1633b918f6.1748874886642.1748874886642.1749050064883.2; hubspotutk=6792f2d6059cc1bc58f90e1633b918f6; sessionid=d1retmjdj1z3kds3lmmi25jt2rvolif6'), 
            (b'sec-fetch-dest', b'empty'), 
            (b'sec-fetch-mode', b'websocket'), 
            (b'sec-fetch-site', b'same-origin'), 
            (b'pragma', b'no-cache'), 
            (b'cache-control', b'no-cache'), 
            (b'upgrade', b'websocket')
            ], 
        'query_string': b'', 
        'client': ['127.0.0.1', 37888], 
        'server': ['127.0.0.1', 8000], 
        'subprotocols': [], 
        'asgi': {'version': '3.0'}, 
        'cookies': {
            'csrftoken': 'xa6Vc2LB1UqGcRcvJcD7ubSbmJhOfaQF', 
            '_ga_S5QK8VSK84': 'GS1.1.1740562390.1.1.1740562437.13.0.0', 
            '_ga': 'GA1.1.722471364.1740562390', 
            'i18n_redirected': 'fr', 
            'Idea-222ad569': '948cdcf9-49b0-49fd-8e7e-619d82b129df', 
            '_ga_GQJEC1951X': 'GS2.1.s1749050054$o5$g1$t1749050111$j3$l0$h1403485809', 
            '_gcl_au': '1.1.732818395.1748874880', 
            '__hstc': '181257784.6792f2d6059cc1bc58f90e1633b918f6.1748874886642.1748874886642.1749050064883.2', 
            'hubspotutk': '6792f2d6059cc1bc58f90e1633b918f6', 
            'sessionid': 'd1retmjdj1z3kds3lmmi25jt2rvolif6'
            }, 
        'session': None, 
        'user': None, 
        'path_remaining': '', 
        'url_route': {
                'args': (), 
                'kwargs': {
                    'chatroom_name': 'public-chat'
                    }
                }
            }, 
        'channel_layer': None, 
        'channel_name': 'specific.62b1d36943c8414ab06cb29033f5505d!06d847a4f7ec484e94d66a0a66a9147e', 
        'channel_receive': None, 
        'base_send': None
        }
